# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Downloads/train (1) (1).csv")
display(df)
survival_rate = df.groupby("Pclass")["Survived"].mean()

# Plot
plt.bar(survival_rate.index, survival_rate.values, color='skyblue')
plt.xlabel("Passenger Class (Pclass)")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Passenger Class")
plt.show()




import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Downloads/train (1) (1).csv")

# Count survivors and non-survivors
survival_counts = df["Survived"].value_counts()

# Plot
plt.pie(survival_counts, labels=["Non-Survived", "Survived"], autopct="%1.1f%%", colors=["lightcoral", "lightgreen"])
plt.title("Proportion of Survivors vs Non-Survivors")
plt.show()





import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Downloads/train (1) (1).csv")

# Create grouped data
grouped = df.groupby(["Pclass", "Sex", "Survived"]).size().unstack(fill_value=0)

# Plot
grouped.plot(kind="bar", stacked=True, color=["lightcoral", "lightgreen"])
plt.xlabel("Passenger Class & Sex")
plt.ylabel("Number of Passengers")
plt.title("Survivors vs Non-Survivors by Pclass & Sex")
plt.legend(["Non-Survived", "Survived"])
plt.show()




import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Downloads/train (1) (1).csv")

survival_rate = df.groupby("Pclass")["Survived"].mean()

plt.bar(survival_rate.index, survival_rate.values, color="orange")
plt.xlabel("Passenger Class (Pclass)")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Passenger Class")
plt.show()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
